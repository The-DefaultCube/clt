# %% [markdown]
# <a href="https://colab.research.google.com/github/The-DefaultCube/clt/blob/main/CLT_and_WLLN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
plt.rcParams['figure.figsize'] = [12, 8]

import numpy as np

# %%
n = 10# no. of iid rvs
m = 10000 # samples
X = np.random.rand(m, n)*10

plt.hist(X[:,1], bins=m//100); # pdf of xi

# %%
Y = np.sum(X, axis = 1, keepdims=True)
plt.hist(Y, bins=m//100);

# %%
# clt
